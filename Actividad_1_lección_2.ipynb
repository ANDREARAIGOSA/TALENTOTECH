# %% [markdown]
# <a href="https://colab.research.google.com/github/ANDREARAIGOSA/TALENTOTECH/blob/main/Actividad_1_lecci%C3%B3n_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# carga de paquetes y funciones para generar gráficos
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

rango = np.random.RandomState(0)
x = np.linspace (0, 10, 500)
y = np.cumsum (rango.randn (500, 6), 0)


# graficar los datos
plt.plot (x,y)
plt.legend ('ABCDEF', ncol=2, loc='upper left');
sns.set() # carga de estilos de seaborn
# luego, se dibuja exactamente igual que en el
# Código anterior
plt.plot (x, y)
plt.legend ( 'ABCDEF', ncol=2, loc='upper left')

# %%
# carga de paquetes y funciones para generar gráficos
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# generando puntos de una función
x_val= np.linspace (0, 10, 20)
y_val = x_val ** 2
plt.scatter (x_val, y_val)

# %%
# generando puntos de una función
x_val= np.linspace (0, 10, 20)
y_val = x_val ** 2

plt.scatter (x_val, y_val)
plt.title ("Desplazamiento") #Título del gráfico
plt.xlabel ("tiempo [segundos]") #etiqueta del eje x
plt.ylabel ("Distancia [metros]") #etiqueta del eje y
# Out:
# Text(0, 0.5, 'Distancia [metros]')

# %%
plt.scatter (x_val, y_val, marker= '*')
plt.title ("Desplazamiento")
plt.xlabel ("Tiempo [Segundos]")
plt.ylabel ("Distancia [Metros]")
# Out:
# Text(0, 0.5, 'Distancia [Metros]')

# %%
# carga de paquetes y funciones para generar gráficos
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


plt.plot (x_val, y_val, color='r')
plt.scatter (x_val, y_val, marker=',' ,color= 'g',s=150)
plt.title ("Desplazamiento")
plt.xlabel ("Tiempo [Segundos]")
plt.ylabel ("Distancia [Metros]")
# Out:
# Text(0, 0.5, 'Distancia [Metros]')

# %%
# carga de paquetes y funciones para generar gráficos
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data= np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data= pd.DataFrame(data, columns= ['x', 'y'])
for col in 'xy':
  plt.hist (data[col], alpha= 0.5)

# %%
# carga de paquetes y funciones para generar gráficos
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd


#crear un DataFrame con los datos de ejemplo

data= np.random.multivariate_normal([0, 0], [[5, 2], [2, 2]], size=2000)
data= pd.DataFrame(data, columns= ['x', 'y'])
for col in 'xy':
  plt.hist (data[col], alpha= 0.5)

#Calcular la matriz de correlación
corr_matrix= pd.DataFrame.corr()

#Mostrar la matriz de correlación
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1509ea895ff0> in <cell line: 16>()
#      14
#      15 #Calcular la matriz de correlación
# ---> 16 corr_matrix= pd.DataFrame.corr()
#      17
#      18 #Mostrar la matriz de correlación
#
# TypeError: DataFrame.corr() missing 1 required positional argument: 'self'

# %%
for col in 'xy':
  sns.kdeplot (data[col], shade=True)
# Out:
# <ipython-input-46-281fe9a0bb73>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot (data[col], shade=True)
# <ipython-input-46-281fe9a0bb73>:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot (data[col], shade=True)

# %%
sns.distplot (data['x'])
sns.distplot(data['y'])
# Out:
# <ipython-input-47-f5d29cf85cfb>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot (data['x'])
# <ipython-input-47-f5d29cf85cfb>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['y'])
# <Axes: xlabel='y', ylabel='Density'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

iris = sns.load_dataset ("iris")
iris.head()
sns.pairplot (iris, hue='species', height=2.5);
